# %% [markdown]
# To use ROOT within Google Colab, it seems that the best way is currently through Conda (https://docs.conda.io/en/latest/). So, we first install Conda.

# %%
# !pip install -q condacolab

# %%
import condacolab

# %%
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 23.11.0

# %%
# !conda install ROOT
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - root
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     afterimage-1.21            |    h28ea39c_1005         676 KB  conda-forge
#     anyio-4.6.2.post1          |     pyhd8ed1ab_0         107 KB  conda-forge
#     argon2-cffi-23.1.0         |     pyhd8ed1ab_0          18 KB  conda-forge
#     argon2-cffi-bindings-21.2.0|  py310ha75aee5_5          34 KB  conda-forge
#     arrow-1.3.0                |     pyhd8ed1ab_0          98 KB  conda-forge
#     asttokens-2.4.1            |     pyhd8ed1ab_0          28 KB  conda-forge
#     async-lru-2.0.4            |     pyhd8ed1ab_0          15 KB  conda-forge
#     atk-1.0-2.38.0             |       h04ea711_2         348 KB  conda-forge
#     attrs-24.2.0               |     pyh71513ae_0          55 KB  conda-forge
#     babel-2.14.0               |     pyhd8ed1ab_0         7.3 MB  conda-forge
#     beautifulsoup4-4.12.3      |     pyha770c72_0         115 KB  conda-forge
#     binutils-2.40              |       h4852527_7          31 KB  conda-forge
#     binutils_impl_linux-64-2.40|       hf600244_0         5.2 MB  conda-forge
#     binutils_linux-64-2.40     |       hb3c18ed_9          29 KB  conda-forge
#     bleach-6.2.0               |     pyhd8ed1ab_0         130 KB  conda-forge
#     c-compiler-1.7.0           |       hd590300_1           6 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     cairo-1.18.0               |       h3faef2a_0         959 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     cfitsio-4.3.1              |       hbdc6101_0         855 KB  conda-forge
#     comm-0.2.2                 |     pyhd8ed1ab_0          12 KB  conda-forge
#     compilers-1.7.0            |       ha770c72_1           7 KB  conda-forge
#     cxx-compiler-1.7.0         |       h00ab1b0_1           6 KB  conda-forge
#     davix-0.8.6                |       h5f3b820_0         1.1 MB  conda-forge
#     debugpy-1.8.7              |  py310hf71b8c6_0         2.1 MB  conda-forge
#     decorator-5.1.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     defusedxml-0.7.1           |     pyhd8ed1ab_0          23 KB  conda-forge
#     entrypoints-0.4            |     pyhd8ed1ab_0           9 KB  conda-forge
#     exceptiongroup-1.2.2       |     pyhd8ed1ab_0          20 KB  conda-forge
#     executing-2.1.0            |     pyhd8ed1ab_0          28 KB  conda-forge
#     expat-2.6.3                |       h5888daf_0         135 KB  conda-forge
#     fftw-3.3.10                |nompi_hf1063bd_110         2.0 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fortran-compiler-1.7.0     |       heb67821_1           6 KB  conda-forge
#     fqdn-1.5.1                 |     pyhd8ed1ab_0          14 KB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     ftgl-2.4.0                 |       hbcb1f35_0         112 KB  conda-forge
#     gcc-12.4.0                 |       h236703b_1          53 KB  conda-forge
#     gcc_impl_linux-64-12.4.0   |       hb2e57f8_1        59.2 MB  conda-forge
#     gcc_linux-64-12.4.0        |       h6b7512a_5          31 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       hb9ae30d_0         516 KB  conda-forge
#     gettext-0.22.5             |       he02047a_3         468 KB  conda-forge
#     gettext-tools-0.22.5       |       he02047a_3         2.6 MB  conda-forge
#     gfortran-12.4.0            |       h236703b_1          52 KB  conda-forge
#     gfortran_impl_linux-64-12.4.0|       hc568b83_1        14.7 MB  conda-forge
#     gfortran_linux-64-12.4.0   |       hd748a6a_5          30 KB  conda-forge
#     giflib-5.2.2               |       hd590300_0          75 KB  conda-forge
#     gl2ps-1.4.2                |       h0708190_0         147 KB  conda-forge
#     glew-2.1.0                 |       h9c3ff4c_2         647 KB  conda-forge
#     graphite2-1.3.13           |    h59595ed_1003          95 KB  conda-forge
#     graphviz-9.0.0             |       h78e8752_1         2.2 MB  conda-forge
#     gsl-2.7                    |       he838d99_0         3.2 MB  conda-forge
#     gsoap-2.8.123              |       h8dc497d_0         1.8 MB  conda-forge
#     gtest-1.14.0               |       h434a139_2         394 KB  conda-forge
#     gtk2-2.24.33               |       h280cfa0_4         6.2 MB  conda-forge
#     gts-0.7.6                  |       h977cf35_4         311 KB  conda-forge
#     gxx-12.4.0                 |       h236703b_1          52 KB  conda-forge
#     gxx_impl_linux-64-12.4.0   |       h613a52c_1        12.1 MB  conda-forge
#     gxx_linux-64-12.4.0        |       h8489865_5          30 KB  conda-forge
#     h11-0.14.0                 |     pyhd8ed1ab_0          47 KB  conda-forge
#     h2-4.1.0                   |     pyhd8ed1ab_0          46 KB  conda-forge
#     harfbuzz-8.5.0             |       hfac3d4d_0         1.5 MB  conda-forge
#     hpack-4.0.0                |     pyh9f0ad1d_0          25 KB  conda-forge
#     httpcore-1.0.6             |     pyhd8ed1ab_0          45 KB  conda-forge
#     httpx-0.27.2               |     pyhd8ed1ab_0          64 KB  conda-forge
#     hyperframe-6.0.1           |     pyhd8ed1ab_0          14 KB  conda-forge
#     importlib-metadata-8.5.0   |     pyha770c72_0          28 KB  conda-forge
#     importlib_metadata-8.5.0   |       hd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-6.4.5  |     pyhd8ed1ab_0          32 KB  conda-forge
#     ipykernel-6.29.5           |     pyh3099207_0         116 KB  conda-forge
#     ipyparallel-8.8.0          |     pyhd8ed1ab_0         201 KB  conda-forge
#     ipython-8.29.0             |     pyh707e725_0         585 KB  conda-forge
#     isoduration-20.11.0        |     pyhd8ed1ab_0          17 KB  conda-forge
#     jedi-0.19.1                |     pyhd8ed1ab_0         822 KB  conda-forge
#     jinja2-3.1.4               |     pyhd8ed1ab_0         109 KB  conda-forge
#     json5-0.9.25               |     pyhd8ed1ab_0          27 KB  conda-forge
#     jsonschema-4.23.0          |     pyhd8ed1ab_0          73 KB  conda-forge
#     jsonschema-specifications-2024.10.1|     pyhd8ed1ab_0          16 KB  conda-forge
#     jsonschema-with-format-nongpl-4.23.0|       hd8ed1ab_0           7 KB  conda-forge
#     jupyter-lsp-2.2.5          |     pyhd8ed1ab_0          54 KB  conda-forge
#     jupyter_client-8.6.3       |     pyhd8ed1ab_0         104 KB  conda-forge
#     jupyter_core-5.7.2         |     pyh31011fe_1          56 KB  conda-forge
#     jupyter_events-0.10.0      |     pyhd8ed1ab_0          21 KB  conda-forge
#     jupyter_server-2.14.2      |     pyhd8ed1ab_0         316 KB  conda-forge
#     jupyter_server_terminals-0.5.3|     pyhd8ed1ab_0          19 KB  conda-forge
#     jupyterlab-4.2.5           |     pyhd8ed1ab_0         7.0 MB  conda-forge
#     jupyterlab_pygments-0.3.0  |     pyhd8ed1ab_1          18 KB  conda-forge
#     jupyterlab_server-2.27.3   |     pyhd8ed1ab_0          48 KB  conda-forge
#     kernel-headers_linux-64-3.10.0|      he073ed8_18         921 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libasprintf-0.22.5         |       he8f35ee_3          42 KB  conda-forge
#     libasprintf-devel-0.22.5   |       he8f35ee_3          33 KB  conda-forge
#     libblas-3.9.0              |25_linux64_openblas          15 KB  conda-forge
#     libcblas-3.9.0             |25_linux64_openblas          15 KB  conda-forge
#     libcxx-16.0.6              |       he02047a_2         606 KB  conda-forge
#     libcxxabi-16.0.6           |       h4bc722e_2         150 KB  conda-forge
#     libdeflate-1.20            |       hd590300_0          70 KB  conda-forge
#     libexpat-2.6.3             |       h5888daf_0          72 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-devel_linux-64-12.4.0|     ha4f9413_101         2.4 MB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgd-2.3.3                |       h119a65a_9         219 KB  conda-forge
#     libgettextpo-0.22.5        |       he02047a_3         167 KB  conda-forge
#     libgettextpo-devel-0.22.5  |       he02047a_3          36 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_1          53 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_1          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hd5240d6_1         1.4 MB  conda-forge
#     libglib-2.80.2             |       hf974151_0         3.7 MB  conda-forge
#     libglu-9.0.0               |    hac7e632_1003         323 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     libhwloc-2.11.2            |default_he43201b_1000         2.3 MB  conda-forge
#     libjpeg-turbo-3.0.0        |       hd590300_1         604 KB  conda-forge
#     liblapack-3.9.0            |25_linux64_openblas          15 KB  conda-forge
#     libllvm13-13.0.1           |       hf817b99_2        33.6 MB  conda-forge
#     libllvm14-14.0.6           |       hcd5def8_4        30.0 MB  conda-forge
#     libopenblas-0.3.28         |pthreads_h94d23a6_0         5.3 MB  conda-forge
#     libpng-1.6.43              |       h2797004_0         281 KB  conda-forge
#     librsvg-2.58.1             |       hadf69e7_0         6.0 MB  conda-forge
#     libsanitizer-12.4.0        |       h46f95d5_1         3.8 MB  conda-forge
#     libsodium-1.0.18           |       h36c2ea0_1         366 KB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libstdcxx-devel_linux-64-12.4.0|     ha4f9413_101        11.3 MB  conda-forge
#     libtiff-4.6.0              |       h1dd3fc0_3         276 KB  conda-forge
#     libwebp-1.4.0              |       h2c329e2_0          90 KB  conda-forge
#     libwebp-base-1.4.0         |       hd590300_0         429 KB  conda-forge
#     libxcb-1.15                |       h0b41bf4_0         375 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libxml2-2.12.7             |       hc051c1a_1         688 KB  conda-forge
#     llvmlite-0.42.0            |  py310h1b8f574_1         3.2 MB  conda-forge
#     markupsafe-3.0.2           |  py310h89163eb_0          22 KB  conda-forge
#     matplotlib-inline-0.1.7    |     pyhd8ed1ab_0          14 KB  conda-forge
#     metakernel-0.30.2          |     pyhd8ed1ab_0         182 KB  conda-forge
#     mistune-3.0.2              |     pyhd8ed1ab_0          64 KB  conda-forge
#     nbclient-0.10.0            |     pyhd8ed1ab_0          27 KB  conda-forge
#     nbconvert-core-7.16.4      |     pyhd8ed1ab_1         185 KB  conda-forge
#     nbformat-5.10.4            |     pyhd8ed1ab_0          99 KB  conda-forge
#     nest-asyncio-1.6.0         |     pyhd8ed1ab_0          11 KB  conda-forge
#     nlohmann_json-3.11.2       |       h27087fc_0         112 KB  conda-forge
#     notebook-7.2.2             |     pyhd8ed1ab_0         3.7 MB  conda-forge
#     notebook-shim-0.2.4        |     pyhd8ed1ab_0          16 KB  conda-forge
#     numba-0.59.1               |  py310h7dc5dd1_0         4.1 MB  conda-forge
#     numpy-1.26.4               |  py310hb13e2d6_0         6.7 MB  conda-forge
#     openssl-3.3.2              |       hb9d3cd8_0         2.8 MB  conda-forge
#     overrides-7.7.0            |     pyhd8ed1ab_0          30 KB  conda-forge
#     pandocfilters-1.5.0        |     pyhd8ed1ab_0          11 KB  conda-forge
#     pango-1.54.0               |       h84a9a3c_0         438 KB  conda-forge
#     parso-0.8.4                |     pyhd8ed1ab_0          73 KB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     pcre2-10.43                |       hcad00b1_0         929 KB  conda-forge
#     pexpect-4.9.0              |     pyhd8ed1ab_0          52 KB  conda-forge
#     pickleshare-0.7.5          |          py_1003           9 KB  conda-forge
#     pixman-0.43.2              |       h59595ed_0         378 KB  conda-forge
#     pkgutil-resolve-name-1.3.10|     pyhd8ed1ab_1          11 KB  conda-forge
#     portalocker-2.10.1         |  py310hff52083_1          37 KB  conda-forge
#     prometheus_client-0.21.0   |     pyhd8ed1ab_0          48 KB  conda-forge
#     prompt-toolkit-3.0.48      |     pyha770c72_0         264 KB  conda-forge
#     psutil-6.1.0               |  py310ha75aee5_0         360 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     ptyprocess-0.7.0           |     pyhd3deb0d_0          16 KB  conda-forge
#     pure_eval-0.2.3            |     pyhd8ed1ab_0          16 KB  conda-forge
#     pygments-2.18.0            |     pyhd8ed1ab_0         859 KB  conda-forge
#     pythia8-8.310              |  py310hea249c9_1        29.8 MB  conda-forge
#     python-dateutil-2.9.0      |     pyhd8ed1ab_0         218 KB  conda-forge
#     python-fastjsonschema-2.20.0|     pyhd8ed1ab_0         221 KB  conda-forge
#     python-json-logger-2.0.7   |     pyhd8ed1ab_0          13 KB  conda-forge
#     pytz-2024.2                |     pyhd8ed1ab_0         183 KB  conda-forge
#     pyyaml-6.0.2               |  py310ha75aee5_1         178 KB  conda-forge
#     pyzmq-26.2.0               |  py310h71f11fc_1         330 KB  conda-forge
#     referencing-0.35.1         |     pyhd8ed1ab_0          41 KB  conda-forge
#     rfc3339-validator-0.1.4    |     pyhd8ed1ab_0           8 KB  conda-forge
#     rfc3986-validator-0.1.1    |     pyh9f0ad1d_0           8 KB  conda-forge
#     root-6.30.4                |  py310hcc13569_0          32 KB  conda-forge
#     root_base-6.30.4           |  py310hc6cfe62_0       193.0 MB  conda-forge
#     rpds-py-0.20.1             |  py310h505e2c1_0         326 KB  conda-forge
#     scitokens-cpp-1.0.2        |       haea88ab_0         1.7 MB  conda-forge
#     send2trash-1.8.3           |     pyh0d859eb_0          22 KB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     sniffio-1.3.1              |     pyhd8ed1ab_0          15 KB  conda-forge
#     soupsieve-2.5              |     pyhd8ed1ab_1          36 KB  conda-forge
#     stack_data-0.6.2           |     pyhd8ed1ab_0          26 KB  conda-forge
#     sysroot_linux-64-2.17      |      h4a8ded7_18        14.8 MB  conda-forge
#     tbb-2022.0.0               |       hceb3a55_0         174 KB  conda-forge
#     terminado-0.18.1           |     pyh0d859eb_0          22 KB  conda-forge
#     tinycss2-1.4.0             |     pyhd8ed1ab_0          28 KB  conda-forge
#     tomli-2.0.2                |     pyhd8ed1ab_0          18 KB  conda-forge
#     tornado-6.4.1              |  py310ha75aee5_1         635 KB  conda-forge
#     traitlets-5.14.3           |     pyhd8ed1ab_0         108 KB  conda-forge
#     types-python-dateutil-2.9.0.20241003|     pyhff2d567_0          21 KB  conda-forge
#     typing-extensions-4.12.2   |       hd8ed1ab_0          10 KB  conda-forge
#     typing_extensions-4.12.2   |     pyha770c72_0          39 KB  conda-forge
#     typing_utils-0.1.0         |     pyhd8ed1ab_0          14 KB  conda-forge
#     uri-template-1.3.0         |     pyhd8ed1ab_0          23 KB  conda-forge
#     vdt-0.4.4                  |       h59595ed_0          30 KB  conda-forge
#     vector-classes-1.4.4       |       h00ab1b0_0         244 KB  conda-forge
#     wcwidth-0.2.13             |     pyhd8ed1ab_0          32 KB  conda-forge
#     webcolors-24.8.0           |     pyhd8ed1ab_0          18 KB  conda-forge
#     webencodings-0.5.1         |     pyhd8ed1ab_2          15 KB  conda-forge
#     websocket-client-1.8.0     |     pyhd8ed1ab_0          46 KB  conda-forge
#     xorg-fixesproto-5.0        |    hb9d3cd8_1003          11 KB  conda-forge
#     xorg-kbproto-1.0.7         |    hb9d3cd8_1003          30 KB  conda-forge
#     xorg-libice-1.1.1          |       hb9d3cd8_1          57 KB  conda-forge
#     xorg-libsm-1.2.4           |       he73a12e_1          27 KB  conda-forge
#     xorg-libx11-1.8.9          |       h8ee46fc_0         809 KB  conda-forge
#     xorg-libxau-1.0.11         |       hb9d3cd8_1          14 KB  conda-forge
#     xorg-libxcursor-1.2.0      |       h0b41bf4_1          31 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     xorg-libxft-2.3.8          |       hf69aa0a_0          58 KB  conda-forge
#     xorg-libxpm-3.5.17         |       hd590300_0          63 KB  conda-forge
#     xorg-libxrender-0.9.11     |       hd590300_0          37 KB  conda-forge
#     xorg-libxt-1.3.0           |       hd590300_1         370 KB  conda-forge
#     xorg-renderproto-0.11.1    |    hb9d3cd8_1003          12 KB  conda-forge
#     xorg-xextproto-7.3.0       |    hb9d3cd8_1004          30 KB  conda-forge
#     xorg-xproto-7.0.31         |    hb9d3cd8_1008          72 KB  conda-forge
#     xrootd-5.6.8               |  py310h4d51e2b_0         3.5 MB  conda-forge
#     xxhash-0.8.2               |       hd590300_0          95 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     zeromq-4.3.5               |       h75354e8_4         345 KB  conda-forge
#     zipp-3.20.2                |     pyhd8ed1ab_0          21 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       525.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   afterimage         conda-forge/linux-64::afterimage-1.21-h28ea39c_1005
#   anyio              conda-forge/noarch::anyio-4.6.2.post1-pyhd8ed1ab_0
#   argon2-cffi        conda-forge/noarch::argon2-cffi-23.1.0-pyhd8ed1ab_0
#   argon2-cffi-bindi~ conda-forge/linux-64::argon2-cffi-bindings-21.2.0-py310ha75aee5_5
#   arrow              conda-forge/noarch::arrow-1.3.0-pyhd8ed1ab_0
#   asttokens          conda-forge/noarch::asttokens-2.4.1-pyhd8ed1ab_0
#   async-lru          conda-forge/noarch::async-lru-2.0.4-pyhd8ed1ab_0
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.38.0-h04ea711_2
#   attrs              conda-forge/noarch::attrs-24.2.0-pyh71513ae_0
#   babel              conda-forge/noarch::babel-2.14.0-pyhd8ed1ab_0
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.12.3-pyha770c72_0
#   binutils           conda-forge/linux-64::binutils-2.40-h4852527_7
#   binutils_impl_lin~ conda-forge/linux-64::binutils_impl_linux-64-2.40-hf600244_0
#   binutils_linux-64  conda-forge/linux-64::binutils_linux-64-2.40-hb3c18ed_9
#   bleach             conda-forge/noarch::bleach-6.2.0-pyhd8ed1ab_0
#   c-compiler         conda-forge/linux-64::c-compiler-1.7.0-hd590300_1
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   cairo              conda-forge/linux-64::cairo-1.18.0-h3faef2a_0
#   cfitsio            conda-forge/linux-64::cfitsio-4.3.1-hbdc6101_0
#   comm               conda-forge/noarch::comm-0.2.2-pyhd8ed1ab_0
#   compilers          conda-forge/linux-64::compilers-1.7.0-ha770c72_1
#   cxx-compiler       conda-forge/linux-64::cxx-compiler-1.7.0-h00ab1b0_1
#   davix              conda-forge/linux-64::davix-0.8.6-h5f3b820_0
#   debugpy            conda-forge/linux-64::debugpy-1.8.7-py310hf71b8c6_0
#   decorator          conda-forge/noarch::decorator-5.1.1-pyhd8ed1ab_0
#   defusedxml         conda-forge/noarch::defusedxml-0.7.1-pyhd8ed1ab_0
#   entrypoints        conda-forge/noarch::entrypoints-0.4-pyhd8ed1ab_0
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.2.2-pyhd8ed1ab_0
#   executing          conda-forge/noarch::executing-2.1.0-pyhd8ed1ab_0
#   expat              conda-forge/linux-64::expat-2.6.3-h5888daf_0
#   fftw               conda-forge/linux-64::fftw-3.3.10-nompi_hf1063bd_110
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fortran-compiler   conda-forge/linux-64::fortran-compiler-1.7.0-heb67821_1
#   fqdn               conda-forge/noarch::fqdn-1.5.1-pyhd8ed1ab_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   ftgl               conda-forge/linux-64::ftgl-2.4.0-hbcb1f35_0
#   gcc                conda-forge/linux-64::gcc-12.4.0-h236703b_1
#   gcc_impl_linux-64  conda-forge/linux-64::gcc_impl_linux-64-12.4.0-hb2e57f8_1
#   gcc_linux-64       conda-forge/linux-64::gcc_linux-64-12.4.0-h6b7512a_5
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   gettext            conda-forge/linux-64::gettext-0.22.5-he02047a_3
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.22.5-he02047a_3
#   gfortran           conda-forge/linux-64::gfortran-12.4.0-h236703b_1
#   gfortran_impl_lin~ conda-forge/linux-64::gfortran_impl_linux-64-12.4.0-hc568b83_1
#   gfortran_linux-64  conda-forge/linux-64::gfortran_linux-64-12.4.0-hd748a6a_5
#   giflib             conda-forge/linux-64::giflib-5.2.2-hd590300_0
#   gl2ps              conda-forge/linux-64::gl2ps-1.4.2-h0708190_0
#   glew               conda-forge/linux-64::glew-2.1.0-h9c3ff4c_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h59595ed_1003
#   graphviz           conda-forge/linux-64::graphviz-9.0.0-h78e8752_1
#   gsl                conda-forge/linux-64::gsl-2.7-he838d99_0
#   gsoap              conda-forge/linux-64::gsoap-2.8.123-h8dc497d_0
#   gtest              conda-forge/linux-64::gtest-1.14.0-h434a139_2
#   gtk2               conda-forge/linux-64::gtk2-2.24.33-h280cfa0_4
#   gts                conda-forge/linux-64::gts-0.7.6-h977cf35_4
#   gxx                conda-forge/linux-64::gxx-12.4.0-h236703b_1
#   gxx_impl_linux-64  conda-forge/linux-64::gxx_impl_linux-64-12.4.0-h613a52c_1
#   gxx_linux-64       conda-forge/linux-64::gxx_linux-64-12.4.0-h8489865_5
#   h11                conda-forge/noarch::h11-0.14.0-pyhd8ed1ab_0
#   h2                 conda-forge/noarch::h2-4.1.0-pyhd8ed1ab_0
#   harfbuzz           conda-forge/linux-64::harfbuzz-8.5.0-hfac3d4d_0
#   hpack              conda-forge/noarch::hpack-4.0.0-pyh9f0ad1d_0
#   httpcore           conda-forge/noarch::httpcore-1.0.6-pyhd8ed1ab_0
#   httpx              conda-forge/noarch::httpx-0.27.2-pyhd8ed1ab_0
#   hyperframe         conda-forge/noarch::hyperframe-6.0.1-pyhd8ed1ab_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.5.0-pyha770c72_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-8.5.0-hd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.4.5-pyhd8ed1ab_0
#   ipykernel          conda-forge/noarch::ipykernel-6.29.5-pyh3099207_0
#   ipyparallel        conda-forge/noarch::ipyparallel-8.8.0-pyhd8ed1ab_0
#   ipython            conda-forge/noarch::ipython-8.29.0-pyh707e725_0
#   isoduration        conda-forge/noarch::isoduration-20.11.0-pyhd8ed1ab_0
#   jedi               conda-forge/noarch::jedi-0.19.1-pyhd8ed1ab_0
#   jinja2             conda-forge/noarch::jinja2-3.1.4-pyhd8ed1ab_0
#   json5              conda-forge/noarch::json5-0.9.25-pyhd8ed1ab_0
#   jsonschema         conda-forge/noarch::jsonschema-4.23.0-pyhd8ed1ab_0
#   jsonschema-specif~ conda-forge/noarch::jsonschema-specifications-2024.10.1-pyhd8ed1ab_0
#   jsonschema-with-f~ conda-forge/noarch::jsonschema-with-format-nongpl-4.23.0-hd8ed1ab_0
#   jupyter-lsp        conda-forge/noarch::jupyter-lsp-2.2.5-pyhd8ed1ab_0
#   jupyter_client     conda-forge/noarch::jupyter_client-8.6.3-pyhd8ed1ab_0
#   jupyter_core       conda-forge/noarch::jupyter_core-5.7.2-pyh31011fe_1
#   jupyter_events     conda-forge/noarch::jupyter_events-0.10.0-pyhd8ed1ab_0
#   jupyter_server     conda-forge/noarch::jupyter_server-2.14.2-pyhd8ed1ab_0
#   jupyter_server_te~ conda-forge/noarch::jupyter_server_terminals-0.5.3-pyhd8ed1ab_0
#   jupyterlab         conda-forge/noarch::jupyterlab-4.2.5-pyhd8ed1ab_0
#   jupyterlab_pygmen~ conda-forge/noarch::jupyterlab_pygments-0.3.0-pyhd8ed1ab_1
#   jupyterlab_server  conda-forge/noarch::jupyterlab_server-2.27.3-pyhd8ed1ab_0
#   kernel-headers_li~ conda-forge/noarch::kernel-headers_linux-64-3.10.0-he073ed8_18
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.22.5-he8f35ee_3
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.22.5-he8f35ee_3
#   libblas            conda-forge/linux-64::libblas-3.9.0-25_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-25_linux64_openblas
#   libcxx             conda-forge/linux-64::libcxx-16.0.6-he02047a_2
#   libcxxabi          conda-forge/linux-64::libcxxabi-16.0.6-h4bc722e_2
#   libdeflate         conda-forge/linux-64::libdeflate-1.20-hd590300_0
#   libexpat           conda-forge/linux-64::libexpat-2.6.3-h5888daf_0
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libgcc-devel_linu~ conda-forge/noarch::libgcc-devel_linux-64-12.4.0-ha4f9413_101
#   libgd              conda-forge/linux-64::libgd-2.3.3-h119a65a_9
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.22.5-he02047a_3
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.22.5-he02047a_3
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_1
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hd5240d6_1
#   libglib            conda-forge/linux-64::libglib-2.80.2-hf974151_0
#   libglu             conda-forge/linux-64::libglu-9.0.0-hac7e632_1003
#   libhwloc           conda-forge/linux-64::libhwloc-2.11.2-default_he43201b_1000
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-25_linux64_openblas
#   libllvm13          conda-forge/linux-64::libllvm13-13.0.1-hf817b99_2
#   libllvm14          conda-forge/linux-64::libllvm14-14.0.6-hcd5def8_4
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.28-pthreads_h94d23a6_0
#   libpng             conda-forge/linux-64::libpng-1.6.43-h2797004_0
#   librsvg            conda-forge/linux-64::librsvg-2.58.1-hadf69e7_0
#   libsanitizer       conda-forge/linux-64::libsanitizer-12.4.0-h46f95d5_1
#   libsodium          conda-forge/linux-64::libsodium-1.0.18-h36c2ea0_1
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libstdcxx-devel_l~ conda-forge/noarch::libstdcxx-devel_linux-64-12.4.0-ha4f9413_101
#   libtiff            conda-forge/linux-64::libtiff-4.6.0-h1dd3fc0_3
#   libwebp            conda-forge/linux-64::libwebp-1.4.0-h2c329e2_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.4.0-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   llvmlite           conda-forge/linux-64::llvmlite-0.42.0-py310h1b8f574_1
#   markupsafe         conda-forge/linux-64::markupsafe-3.0.2-py310h89163eb_0
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.7-pyhd8ed1ab_0
#   metakernel         conda-forge/noarch::metakernel-0.30.2-pyhd8ed1ab_0
#   mistune            conda-forge/noarch::mistune-3.0.2-pyhd8ed1ab_0
#   nbclient           conda-forge/noarch::nbclient-0.10.0-pyhd8ed1ab_0
#   nbconvert-core     conda-forge/noarch::nbconvert-core-7.16.4-pyhd8ed1ab_1
#   nbformat           conda-forge/noarch::nbformat-5.10.4-pyhd8ed1ab_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.6.0-pyhd8ed1ab_0
#   nlohmann_json      conda-forge/linux-64::nlohmann_json-3.11.2-h27087fc_0
#   notebook           conda-forge/noarch::notebook-7.2.2-pyhd8ed1ab_0
#   notebook-shim      conda-forge/noarch::notebook-shim-0.2.4-pyhd8ed1ab_0
#   numba              conda-forge/linux-64::numba-0.59.1-py310h7dc5dd1_0
#   numpy              conda-forge/linux-64::numpy-1.26.4-py310hb13e2d6_0
#   overrides          conda-forge/noarch::overrides-7.7.0-pyhd8ed1ab_0
#   pandocfilters      conda-forge/noarch::pandocfilters-1.5.0-pyhd8ed1ab_0
#   pango              conda-forge/linux-64::pango-1.54.0-h84a9a3c_0
#   parso              conda-forge/noarch::parso-0.8.4-pyhd8ed1ab_0
#   pcre               conda-forge/linux-64::pcre-8.45-h9c3ff4c_0
#   pcre2              conda-forge/linux-64::pcre2-10.43-hcad00b1_0
#   pexpect            conda-forge/noarch::pexpect-4.9.0-pyhd8ed1ab_0
#   pickleshare        conda-forge/noarch::pickleshare-0.7.5-py_1003
#   pixman             conda-forge/linux-64::pixman-0.43.2-h59595ed_0
#   pkgutil-resolve-n~ conda-forge/noarch::pkgutil-resolve-name-1.3.10-pyhd8ed1ab_1
#   portalocker        conda-forge/linux-64::portalocker-2.10.1-py310hff52083_1
#   prometheus_client  conda-forge/noarch::prometheus_client-0.21.0-pyhd8ed1ab_0
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.48-pyha770c72_0
#   psutil             conda-forge/linux-64::psutil-6.1.0-py310ha75aee5_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0
#   pure_eval          conda-forge/noarch::pure_eval-0.2.3-pyhd8ed1ab_0
#   pygments           conda-forge/noarch::pygments-2.18.0-pyhd8ed1ab_0
#   pythia8            conda-forge/linux-64::pythia8-8.310-py310hea249c9_1
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0-pyhd8ed1ab_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonschema-2.20.0-pyhd8ed1ab_0
#   python-json-logger conda-forge/noarch::python-json-logger-2.0.7-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2024.2-pyhd8ed1ab_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.2-py310ha75aee5_1
#   pyzmq              conda-forge/linux-64::pyzmq-26.2.0-py310h71f11fc_1
#   referencing        conda-forge/noarch::referencing-0.35.1-pyhd8ed1ab_0
#   rfc3339-validator  conda-forge/noarch::rfc3339-validator-0.1.4-pyhd8ed1ab_0
#   rfc3986-validator  conda-forge/noarch::rfc3986-validator-0.1.1-pyh9f0ad1d_0
#   root               conda-forge/linux-64::root-6.30.4-py310hcc13569_0
#   root_base          conda-forge/linux-64::root_base-6.30.4-py310hc6cfe62_0
#   rpds-py            conda-forge/linux-64::rpds-py-0.20.1-py310h505e2c1_0
#   scitokens-cpp      conda-forge/linux-64::scitokens-cpp-1.0.2-haea88ab_0
#   send2trash         conda-forge/noarch::send2trash-1.8.3-pyh0d859eb_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   sniffio            conda-forge/noarch::sniffio-1.3.1-pyhd8ed1ab_0
#   soupsieve          conda-forge/noarch::soupsieve-2.5-pyhd8ed1ab_1
#   stack_data         conda-forge/noarch::stack_data-0.6.2-pyhd8ed1ab_0
#   sysroot_linux-64   conda-forge/noarch::sysroot_linux-64-2.17-h4a8ded7_18
#   tbb                conda-forge/linux-64::tbb-2022.0.0-hceb3a55_0
#   terminado          conda-forge/noarch::terminado-0.18.1-pyh0d859eb_0
#   tinycss2           conda-forge/noarch::tinycss2-1.4.0-pyhd8ed1ab_0
#   tomli              conda-forge/noarch::tomli-2.0.2-pyhd8ed1ab_0
#   tornado            conda-forge/linux-64::tornado-6.4.1-py310ha75aee5_1
#   traitlets          conda-forge/noarch::traitlets-5.14.3-pyhd8ed1ab_0
#   types-python-date~ conda-forge/noarch::types-python-dateutil-2.9.0.20241003-pyhff2d567_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.12.2-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.12.2-pyha770c72_0
#   typing_utils       conda-forge/noarch::typing_utils-0.1.0-pyhd8ed1ab_0
#   uri-template       conda-forge/noarch::uri-template-1.3.0-pyhd8ed1ab_0
#   vdt                conda-forge/linux-64::vdt-0.4.4-h59595ed_0
#   vector-classes     conda-forge/linux-64::vector-classes-1.4.4-h00ab1b0_0
#   wcwidth            conda-forge/noarch::wcwidth-0.2.13-pyhd8ed1ab_0
#   webcolors          conda-forge/noarch::webcolors-24.8.0-pyhd8ed1ab_0
#   webencodings       conda-forge/noarch::webencodings-0.5.1-pyhd8ed1ab_2
#   websocket-client   conda-forge/noarch::websocket-client-1.8.0-pyhd8ed1ab_0
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-hb9d3cd8_1003
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-hb9d3cd8_1003
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.1-hb9d3cd8_1
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.4-he73a12e_1
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.9-h8ee46fc_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hb9d3cd8_1
#   xorg-libxcursor    conda-forge/linux-64::xorg-libxcursor-1.2.0-h0b41bf4_1
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-libxft        conda-forge/linux-64::xorg-libxft-2.3.8-hf69aa0a_0
#   xorg-libxpm        conda-forge/linux-64::xorg-libxpm-3.5.17-hd590300_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.11-hd590300_0
#   xorg-libxt         conda-forge/linux-64::xorg-libxt-1.3.0-hd590300_1
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-hb9d3cd8_1003
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-hb9d3cd8_1004
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-hb9d3cd8_1008
#   xrootd             conda-forge/linux-64::xrootd-5.6.8-py310h4d51e2b_0
#   xxhash             conda-forge/linux-64::xxhash-0.8.2-hd590300_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   zeromq             conda-forge/linux-64::zeromq-4.3.5-h75354e8_4
#   zipp               conda-forge/noarch::zipp-3.20.2-pyhd8ed1ab_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-hd590300_5
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.8.30-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.8.30-pyhd8ed1ab_0
#   libgcc-ng                               13.2.0-h807b86a_3 --> 14.2.0-h69a702a_1
#   libgomp                                 13.2.0-h807b86a_3 --> 14.2.0-h77fa898_1
#   libxml2                                 2.12.3-h232c23b_0 --> 2.12.7-hc051c1a_1
#   openssl                                  3.2.0-hd590300_1 --> 3.3.2-hb9d3cd8_0
#
#
#
# Downloading and Extracting Packages:
# root_base-6.30.4     | 193.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
# gcc_impl_linux-64-12 | 59.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libllvm13-13.0.1     | 33.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libllvm14-14.0.6     | 30.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# pythia8-8.310        | 29.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# sysroot_linux-64-2.1 | 14.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# gfortran_impl_linux- | 14.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# gxx_impl_linux-64-12 | 12.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 11.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# jupyterlab-4.2.5     | 7.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.59.1         | 4.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsanitizer-12.4.0  | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.80.2       | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# root_base-6.30.4     | 193.0 MB  | :   0% 8.093976401405149e-05/1 [00:00<46:00, 2760.72s/it]
#
# libllvm13-13.0.1     | 33.6 MB   | :   0% 0.0004653879368060901/1 [00:00<08:26, 506.54s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :   0% 0.0005234607812089848/1 [00:00<09:37, 577.84s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :   0% 0.0002641296208376088/1 [00:00<20:06, 1207.23s/it]
#
#
# root_base-6.30.4     | 193.0 MB  | :   1% 0.0051801448968992955/1 [00:00<00:50, 50.43s/it]
#
# libllvm13-13.0.1     | 33.6 MB   | :   3% 0.028854052081977586/1 [00:00<00:09,  9.55s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :   4% 0.03507187234100198/1 [00:00<00:08,  9.05s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :   1% 0.006867370141777829/1 [00:00<00:47, 47.65s/it]
#
#
# root_base-6.30.4     | 193.0 MB  | :   4% 0.03747511073850584/1 [00:00<00:07,  7.96s/it]
#
# libllvm13-13.0.1     | 33.6 MB   | :   8% 0.08237366481467795/1 [00:00<00:03,  3.97s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :  14% 0.1418578717076349/1 [00:00<00:02,  2.46s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :   3% 0.027469480567111317/1 [00:00<00:12, 12.91s/it]
#
#
# root_base-6.30.4     | 193.0 MB  | :   6% 0.057548172213990605/1 [00:00<00:06,  6.64s/it]
#
# libllvm13-13.0.1     | 33.6 MB   | :  17% 0.1740550883654777/1 [00:00<00:01,  2.13s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :  26% 0.2554488612299846/1 [00:00<00:01,  1.59s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :   6% 0.0599574239301372/1 [00:00<00:06,  6.63s/it]
#
#
# libllvm14-14.0.6     | 30.0 MB   | :  48% 0.48395753899191074/1 [00:00<00:00,  1.06it/s]
#
# root_base-6.30.4     | 193.0 MB  | :   8% 0.07503116124102573/1 [00:00<00:06,  6.80s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :  35% 0.35019526262881084/1 [00:00<00:00,  1.38s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  12% 0.11780181089357353/1 [00:00<00:03,  3.58s/it]
#
#
# libllvm14-14.0.6     | 30.0 MB   | :  60% 0.6010440403609214/1 [00:00<00:00,  1.05it/s]
#
# root_base-6.30.4     | 193.0 MB  | :   9% 0.09146193333587818/1 [00:00<00:05,  6.58s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :  45% 0.4522701149645629/1 [00:00<00:00,  1.24s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  17% 0.17326903126947138/1 [00:00<00:02,  2.78s/it]
#
#
# libllvm14-14.0.6     | 30.0 MB   | :  71% 0.7134470816751717/1 [00:00<00:00,  1.06it/s]
#
# root_base-6.30.4     | 193.0 MB  | :  11% 0.10781176566671657/1 [00:00<00:05,  6.61s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :  54% 0.5433522908949262/1 [00:00<00:00,  1.19s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  22% 0.22081236302024096/1 [00:00<00:01,  2.53s/it]
#
# libllvm13-13.0.1     | 33.6 MB   | :  55% 0.547296213683962/1 [00:00<00:00,  1.29s/it]
#
#
# root_base-6.30.4     | 193.0 MB  | :  12% 0.12367595941347068/1 [00:00<00:05,  6.72s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :  66% 0.6569432804172759/1 [00:01<00:00,  1.08s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  28% 0.27522306491278836/1 [00:01<00:01,  2.28s/it]
#
# libllvm13-13.0.1     | 33.6 MB   | :  63% 0.6306006543722521/1 [00:01<00:00,  1.27s/it]
#
#
# root_base-6.30.4     | 193.0 MB  | :  14% 0.14002579174430907/1 [00:01<00:05,  6.54s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :  76% 0.7621588974402819/1 [00:01<00:00,  1.04s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  33% 0.33465222960125035/1 [00:01<00:01,  2.06s/it]
#
# root_base-6.30.4     | 193.0 MB  | :  16% 0.15572810596303507/1 [00:01<00:05,  6.58s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  39% 0.3898553203563106/1 [00:01<00:01,  1.98s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | :  87% 0.8710387399317507/1 [00:01<00:00,  1.04s/it]
#
# root_base-6.30.4     | 193.0 MB  | :  17% 0.1723207575859156/1 [00:01<00:05,  6.41s/it]
# root_base-6.30.4     | 193.0 MB  | :  23% 0.2340777975286369/1 [00:01<00:03,  4.25s/it]
# root_base-6.30.4     | 193.0 MB  | :  26% 0.26038322083320364/1 [00:01<00:03,  4.16s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  57% 0.5660297774549957/1 [00:01<00:00,  1.90s/it]
#
#
#
#
# sysroot_linux-64-2.1 | 14.8 MB   | :   0% 0.0010569667943146747/1 [00:01<26:15, 1576.74s/it]
# root_base-6.30.4     | 193.0 MB  | :  28% 0.2846651500374191/1 [00:01<00:03,  4.75s/it]
#
#
#
#
# sysroot_linux-64-2.1 | 14.8 MB   | :  21% 0.20716549168567625/1 [00:01<00:04,  6.17s/it]
# root_base-6.30.4     | 193.0 MB  | :  31% 0.306518886321213/1 [00:01<00:03,  5.19s/it]
#
#
#
#
# sysroot_linux-64-2.1 | 14.8 MB   | :  40% 0.4005904150452617/1 [00:01<00:01,  2.94s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  73% 0.727148846165937/1 [00:01<00:00,  2.00s/it]
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  33% 0.32659194779669776/1 [00:02<00:03,  5.61s/it]
#
#
#
#
#
# gfortran_impl_linux- | 14.7 MB   | :   0% 0.0010621894964473637/1 [00:02<31:35, 1897.99s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  78% 0.7783899926084331/1 [00:02<00:00,  2.23s/it]
#
#
#
#
#
#
# gxx_impl_linux-64-12 | 12.1 MB   | :   0% 0.0012888706522642085/1 [00:02<27:06, 1628.85s/it]
#
#
#
#
# sysroot_linux-64-2.1 | 14.8 MB   | :  76% 0.7641869922895098/1 [00:02<00:00,  1.47s/it]
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  35% 0.3450462139919015/1 [00:02<00:04,  6.53s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  82% 0.8248768058758523/1 [00:02<00:00,  2.50s/it]
#
#
#
#
# sysroot_linux-64-2.1 | 14.8 MB   | :  92% 0.9206180778480817/1 [00:02<00:00,  1.20s/it]
#
#
#
#
#
#
# gxx_impl_linux-64-12 | 12.1 MB   | :  20% 0.20235269240548073/1 [00:02<00:06,  7.84s/it]
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  36% 0.36123416679471176/1 [00:02<00:04,  6.57s/it]
#
#
#
#
#
#
# gxx_impl_linux-64-12 | 12.1 MB   | :  39% 0.3892389369837909/1 [00:02<00:02,  3.68s/it]
#
#
#
#
#
# gfortran_impl_linux- | 14.7 MB   | :  50% 0.5013534423231557/1 [00:02<00:01,  2.44s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  87% 0.8668734155890321/1 [00:02<00:00,  2.66s/it]
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  38% 0.3770983605414659/1 [00:02<00:04,  7.40s/it]
#
#
#
#
#
# gfortran_impl_linux- | 14.7 MB   | :  67% 0.6659928142724971/1 [00:02<00:00,  1.74s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  91% 0.9059645994729982/1 [00:02<00:00,  2.79s/it]
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  39% 0.39126281924392486/1 [00:02<00:04,  7.34s/it]
#
#
#
#
#
# gfortran_impl_linux- | 14.7 MB   | :  86% 0.8635600606117068/1 [00:02<00:00,  1.25s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | :  95% 0.9469046907028276/1 [00:02<00:00,  2.75s/it]
#
#
#
#
#
#
# gxx_impl_linux-64-12 | 12.1 MB   | :  98% 0.9782528250685342/1 [00:02<00:00,  1.22s/it]
# root_base-6.30.4     | 193.0 MB  | :  42% 0.4182967004246181/1 [00:02<00:04,  8.15s/it]
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  43% 0.43383713511531596/1 [00:02<00:04,  7.64s/it]
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  45% 0.4472731359416485/1 [00:02<00:04,  7.63s/it]
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | :   0% 0.0021530273662078254/1 [00:03<23:16, 1399.51s/it]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 11.3 MB   | :  51% 0.512573372566288/1 [00:03<00:01,  3.54s/it]
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  46% 0.462166052520234/1 [00:03<00:03,  7.36s/it]
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | :  40% 0.4047691448470712/1 [00:03<00:03,  5.47s/it]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 11.3 MB   | :  79% 0.7922841108215474/1 [00:03<00:00,  2.04s/it]
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  48% 0.4760067521666368/1 [00:03<00:04,  7.64s/it]
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | :  78% 0.777242879201025/1 [00:03<00:00,  2.52s/it]
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  49% 0.4945419581258546/1 [00:03<00:03,  6.97s/it]
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  51% 0.5110536699847211/1 [00:03<00:03,  6.68s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :   0% 0.002337542641177788/1 [00:03<25:15, 1518.63s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :   0% 0.0025290819728815235/1 [00:03<23:20, 1404.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :   0% 0.002621758386338437/1 [00:03<22:42, 1366.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  29% 0.28831534490849364/1 [00:03<00:06,  9.01s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :   6% 0.06077610867062249/1 [00:03<00:40, 43.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :   3% 0.03408285902239968/1 [00:03<01:15, 78.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :   0% 0.0029403039689975957/1 [00:03<20:56, 1260.50s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :   9% 0.09350170564711152/1 [00:03<00:23, 25.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :   7% 0.06554395965846092/1 [00:03<00:32, 35.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  29% 0.29403039689975957/1 [00:03<00:06,  9.21s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  12% 0.12388975998242277/1 [00:03<00:15, 17.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  10% 0.09700506029452216/1 [00:03<00:18, 20.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  13% 0.1284661609305834/1 [00:03<00:12, 13.95s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  15% 0.15427781431773402/1 [00:04<00:10, 12.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  16% 0.15992726156664466/1 [00:04<00:08, 10.10s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  18% 0.18466586865304527/1 [00:04<00:08,  9.88s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  45% 0.45017659117291114/1 [00:04<00:03,  6.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  19% 0.1913883622027059/1 [00:04<00:06,  7.81s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  22% 0.21505392298835652/1 [00:04<00:06,  7.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  46% 0.45574711519462735/1 [00:04<00:03,  6.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  22% 0.22284946283876714/1 [00:04<00:04,  6.37s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  24% 0.24310443468248996/1 [00:04<00:05,  6.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  26% 0.2569323218611668/1 [00:04<00:03,  5.28s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  27% 0.2734924890178012/1 [00:04<00:04,  5.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  53% 0.5261894058553487/1 [00:04<00:12, 26.19s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  30% 0.3015430007119347/1 [00:04<00:03,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  55% 0.5513398700881721/1 [00:04<00:02,  5.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  56% 0.5586577541095432/1 [00:04<00:02,  5.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  32% 0.3198545231332893/1 [00:04<00:02,  4.23s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  33% 0.32959351240606816/1 [00:04<00:03,  4.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  35% 0.353937382155689/1 [00:04<00:02,  3.86s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  36% 0.3599815667413794/1 [00:04<00:02,  4.26s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  62% 0.6246832473017363/1 [00:04<00:01,  5.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  64% 0.6351056573034807/1 [00:04<00:01,  4.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  39% 0.3853984827917502/1 [00:04<00:02,  3.69s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  39% 0.39036962107669065/1 [00:04<00:02,  4.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  42% 0.4168595834278115/1 [00:04<00:02,  3.56s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  42% 0.41842013277082407/1 [00:04<00:02,  3.94s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  68% 0.6828521326780113/1 [00:04<00:01,  4.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  70% 0.6968520406524302/1 [00:04<00:01,  4.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  45% 0.4483206840638727/1 [00:05<00:01,  3.53s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  45% 0.44647064446495754/1 [00:05<00:02,  3.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  48% 0.47978178469993393/1 [00:05<00:01,  3.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  73% 0.7309046901627603/1 [00:05<00:01,  4.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  75% 0.7497775120943869/1 [00:05<00:01,  4.14s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  47% 0.474521156159091/1 [00:05<00:02,  3.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  51% 0.5112428853359952/1 [00:05<00:01,  3.54s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  50% 0.5025716678532245/1 [00:05<00:01,  3.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  80% 0.7968223755983485/1 [00:05<00:00,  3.97s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  77% 0.7738990837017462/1 [00:05<00:00,  4.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  54% 0.5427039859720565/1 [00:05<00:01,  3.53s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  53% 0.5306221795473579/1 [00:05<00:01,  3.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  84% 0.8379866311643148/1 [00:05<00:00,  3.76s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  81% 0.811835313294969/1 [00:05<00:00,  4.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  57% 0.5741650866081177/1 [00:05<00:01,  3.46s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  56% 0.5586726912414914/1 [00:05<00:01,  3.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  88% 0.8791508867302811/1 [00:05<00:00,  3.61s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  85% 0.8472424609153103/1 [00:05<00:00,  4.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  61% 0.6056261872441789/1 [00:05<00:01,  3.50s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  59% 0.5867232029356249/1 [00:05<00:01,  3.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  92% 0.9173748383272499/1 [00:05<00:00,  3.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  64% 0.6370872878802402/1 [00:05<00:01,  3.43s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  88% 0.8801205265627702/1 [00:05<00:00,  4.00s/it]
#
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  54% 0.5371972137612597/1 [00:05<00:20, 45.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  95% 0.9526584859552211/1 [00:05<00:00,  3.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  67% 0.6685483885163014/1 [00:05<00:01,  3.42s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  64% 0.6428242263238918/1 [00:05<00:01,  3.79s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  91% 0.9129985922102299/1 [00:05<00:00,  3.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  99% 0.9879421335831922/1 [00:05<00:00,  3.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  70% 0.7000094891523627/1 [00:05<00:01,  3.90s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  67% 0.6708747380180252/1 [00:05<00:01,  4.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  94% 0.9433475758848082/1 [00:05<00:00,  4.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  73% 0.7288488314020855/1 [00:06<00:01,  3.81s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  97% 0.971167477586505/1 [00:06<00:00,  4.09s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  70% 0.6965877070709808/1 [00:06<00:01,  4.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | :   0% 0.003025713020427626/1 [00:06<33:40, 2027.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  76% 0.7603099320381467/1 [00:06<00:00,  3.66s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | : 100% 0.9989873792882017/1 [00:06<00:00,  3.99s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  72% 0.7246382187651144/1 [00:06<00:01,  4.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | :   4% 0.039334269265559135/1 [00:06<01:50, 114.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  79% 0.791771032674208/1 [00:06<00:00,  3.57s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  76% 0.7550262731004256/1 [00:06<00:00,  3.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.59.1         | 4.1 MB    | :   0% 0.0037986590158681655/1 [00:06<27:31, 1657.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  55% 0.5452102503986508/1 [00:06<00:23, 52.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | :  91% 0.9071284016730992/1 [00:06<00:00,  1.91s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  92% 0.9186542579828708/1 [00:06<00:00,  1.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.59.1         | 4.1 MB    | :  43% 0.4254498097772345/1 [00:06<00:06, 10.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  58% 0.5762101800160325/1 [00:06<00:11, 26.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  59% 0.5870561083939154/1 [00:06<00:09, 22.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.80.2       | 3.7 MB    | :   0% 0.004187418677717254/1 [00:06<26:27, 1594.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  60% 0.5976592174797561/1 [00:06<00:07, 19.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# root_base-6.30.4     | 193.0 MB  | :  95% 0.952580082681372/1 [00:08<00:00,  4.35s/it]
#
#
# root_base-6.30.4     | 193.0 MB  | : 100% 0.9975016517091705/1 [00:09<00:00,  4.76s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | : 100% 1.0/1 [00:10<00:00, 25.39s/it]
#
#
#
# pythia8-8.310        | 29.8 MB   | : 100% 1.0/1 [00:10<00:00, 25.39s/it]
#
#
#
#
# sysroot_linux-64-2.1 | 14.8 MB   | : 100% 1.0/1 [00:12<00:00,  1.20s/it]
#
#
#
#
#
#
# gxx_impl_linux-64-12 | 12.1 MB   | : 100% 1.0/1 [00:12<00:00,  1.22s/it]
#
#
#
#
#
# gfortran_impl_linux- | 14.7 MB   | : 100% 1.0/1 [00:13<00:00,  1.25s/it]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 11.3 MB   | : 100% 1.0/1 [00:14<00:00,  2.04s/it]
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | : 100% 1.0/1 [00:15<00:00,  2.52s/it]
#
#
#
#
#
#
#
#
#
# jupyterlab-4.2.5     | 7.0 MB    | : 100% 1.0/1 [00:16<00:00,  2.00s/it]
# gcc_impl_linux-64-12 | 59.2 MB   | : 100% 1.0/1 [00:19<00:00,  2.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | : 100% 1.0/1 [00:19<00:00,  3.68s/it]
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | : 100% 1.0/1 [00:20<00:00,  3.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | : 100% 1.0/1 [00:20<00:00, 65.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.1       | 6.0 MB    | : 100% 1.0/1 [00:20<00:00, 65.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.59.1         | 4.1 MB    | : 100% 1.0/1 [00:21<00:00, 21.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.59.1         | 4.1 MB    | : 100% 1.0/1 [00:21<00:00, 21.35s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | : 100% 1.0/1 [00:23<00:00, 69.69s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | : 100% 1.0/1 [00:23<00:00, 69.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | : 100% 1.0/1 [00:23<00:00, 22.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | : 100% 1.0/1 [00:23<00:00, 22.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsanitizer-12.4.0  | 3.8 MB    | : 100% 1.0/1 [00:23<00:00, 21.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsanitizer-12.4.0  | 3.8 MB    | : 100% 1.0/1 [00:23<00:00, 21.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.80.2       | 3.7 MB    | : 100% 1.0/1 [00:23<00:00, 25.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.80.2       | 3.7 MB    | : 100% 1.0/1 [00:23<00:00, 25.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libllvm13-13.0.1     | 33.6 MB   | : 100% 1.0/1 [00:25<00:00, 65.50s/it]
#
# root_base-6.30.4     | 193.0 MB  | : 100% 1.0/1 [00:44<00:00,  4.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# |
# /
# done

# %%
import ROOT

# %% [markdown]
# # **Ajuste de função com o ROOT**

# %%
# 1. Crie um histograma e preencha com dados simulados
hist = ROOT.TH1F("hist", "Exemplo de Ajuste Gaussiano", 100, -10, 10)
for i in range(1000):
    hist.Fill(ROOT.gRandom.Gaus(0, 2))  # Dados com distribuição Gaussiana

# 2. Defina a função de ajuste como uma Gaussiana
# A função Gaussiana é definida como: [0]*exp(-0.5*((x-[1])/[2])**2)
# Onde:
# [0] é a amplitude (altura),
# [1] é a média,
# [2] é o desvio padrão (sigma)
fit_func = ROOT.TF1("fit_func", "[0]*exp(-0.5*((x-[1])/[2])**2)", -10, 10)

# 3. Definir os valores iniciais dos parâmetros para o ajuste
fit_func.SetParameters(100, 0, 2)  # Amplitude, média, desvio padrão

# 4. Ajuste a função ao histograma
hist.Fit(fit_func, "R")  # "R" restringe o ajuste ao intervalo da função

# 5. Exibir o histograma e o ajuste
canvas = ROOT.TCanvas("canvas", "Ajuste Gaussiano", 800, 600)
hist.Draw()
fit_func.Draw("same")  # Desenhe a função ajustada na mesma janela
canvas.Update()

# Manter a janela aberta (apenas se rodando como um script)
input("Pressione Enter para continuar...")
# Out:
# Pressione Enter para continuar...
# ''
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      44.7764
# NDf                       =           54
# Edm                       =  3.53541e-09
# NCalls                    =           81
# p0                        =      40.7556   +/-   1.66912
# p1                        =    0.0263899   +/-   0.06215
# p2                        =       1.8799   +/-   0.0492635
# Warning in <TROOT::Append>: Replacing existing TH1: hist (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %% [markdown]
# # **Atividade: Lendo um arquivo root**
#
# Abra o arquivo "Inv_mass_exemplo_INCT.root"
#
# Acesse o histograma "ULS"
#
# Plote o histograma
#
# Identifique a forma do pico e do fundo e ajuste as funções que os descrevem

# %%
import ROOT

# Abra o arquivo ROOT
file = ROOT.TFile.Open("Inv_mass_exemplo_INCT_dia2.root")

# Acesse o histograma TH1D dentro do arquivo
hist = file.Get("ULS")

file.ls()

if not isinstance(hist, ROOT.TH1D):
    print("O objeto não é um histograma TH1D.")

# Verifique se o histograma foi carregado corretamente
if hist:
    # Imprimir algumas informações sobre o histograma
    print("Nome do histograma:", hist.GetName())
    print("Número de bins:", hist.GetNbinsX())
    print("Contagem no primeiro bin:", hist.GetBinContent(1))

    canvas = ROOT.TCanvas("canvas", "Histograma", 500, 500)
    canvas.SetLeftMargin(0.2)   # Aumentar a margem esquerda para o título do eixo Y
    canvas.SetRightMargin(0.05)  # Margem direita menor (opcional)
    canvas.SetTopMargin(0.1)     # Margem superior (ajustar para dar espaço ao título)
    canvas.SetBottomMargin(0.3) # Aumentar a margem inferior para o título do eixo X


    hist.Draw()

    canvas.Update()

else:
    print("Histograma não encontrado.")


# Crie a função ROOT.TF1
fit_func = ROOT.TF1("fit_func", "[0]*exp(-0.5*((x-[1])/[2])**2) + [3] + [4] * x + [5] * x**2 ", 1.5, 4.5, 6)


# Defina os parâmetros iniciais para o ajuste:
# par[0]: amplitude da Gaussiana
# par[1]: média da Gaussiana
# par[2]: sigma da Gaussiana
# par[3], par[4], par[5]: coeficientes do polinômio de grau 2

fit_func.SetParameters(80, 3.09, 0.2, 1, 1, 1)  # Definir valores iniciais dos parâmetros

# Ajuste a função ao histograma
hist.Fit(fit_func, "R")  # "R" restringe o ajuste ao intervalo da função

print(fit_func.GetParameter(0))


# Acessar os parâmetros da função ajustada gauss
amplitude = fit_func.GetParameter(0)  # Parâmetro 0: Amplitude
media = fit_func.GetParameter(1)      # Parâmetro 1: Média
desvio_padrao = fit_func.GetParameter(2)  # Parâmetro 2: Desvio padrão

gauss = ROOT.TF1("gauss", "[0]*exp(-0.5*((x-[1])/[2])**2)", 1.5, 4.5, 3)
gauss.FixParameter(0, amplitude)
gauss.FixParameter(1, media)
gauss.FixParameter(2, desvio_padrao)

print(amplitude, media, desvio_padrao)

# Acessar os parâmetros da função ajustada pol 2: a + bx + cxx
a = fit_func.GetParameter(3)      # a
b = fit_func.GetParameter(4)      # b
c = fit_func.GetParameter(5)      # c

print(a, b, c)

pol2 = ROOT.TF1("pol2", "[0] + [1] * x + [2] * x**2 ", 1.5, 4.5, 3)
pol2.FixParameter(0, a);
pol2.FixParameter(1, b);
pol2.FixParameter(2, c);



# Desenhe o histograma e o ajuste

fit_func.Draw("same")  # Desenha a função ajustada na mesma janela
pol2.SetLineColor(ROOT.kBlue)  # Define a cor
pol2.SetLineWidth(2)         # Define a largura da linha
pol2.SetLineStyle(1)         # Define o estilo da linha (1 = linha sólida)
pol2.Draw("same")

canvas.Update()

gauss.SetLineColor(ROOT.kGreen)
gauss.SetLineWidth(2)
gauss.SetLineStyle(1)
gauss.Draw("same")

canvas.Update()
# Out:
# Nome do histograma: h0b
# Número de bins: 375
# Contagem no primeiro bin: 4611.0
# 53.69881496675169
# 53.69881496675169 3.056653457981964 -0.05908221736586557
# 52.30124204145819 -9.408827354752585 0.01820491741149125
# TFile**		Inv_mass_exemplo_INCT.root
#  TFile*		Inv_mass_exemplo_INCT.root
#   OBJ: TH1D	h0b	8.0 #leq p_{T} < 15.0 (GeV/c) : 0 at: 0x575292c32530
#   KEY: TH1D	ULS;1	8.0 #leq p_{T} < 15.0 (GeV/c)
#   KEY: TH1D	LS;1	Inv.Mass Pair_ev1+_ev1+
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      73.9831
# NDf                       =           70
# Edm                       =  2.04689e-08
# NCalls                    =         1008
# p0                        =      53.6988   +/-   5.97227
# p1                        =      3.05665   +/-   0.00774522
# p2                        =   -0.0590822   +/-   0.00573624
# p3                        =      52.3012   +/-   7.61283
# p4                        =     -9.40883   +/-   5.19437
# p5                        =    0.0182049   +/-   0.828268
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# <div id="root_plot_1730685317532" style="width: 500px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1730685317532(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.2,"fRightMargin":0.05,"fBottomMargin":0.3,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0.669333321253459,"fY1":-45.87054075472,"fX2":4.72266666968664,"fY2":107.623090239262,"fXtoAbsPixelk":-81.9052113745786,"fXtoPixelk":-81.9052113745786,"fXtoPixel":122.368420596774,"fYtoAbsPixelk":330.946019966163,"fYtoPixelk":330.946019966163,"fYtoPixel":-3.07504615627019,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":496,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":0.669333321253459,"fPixeltoXk":0.669333321253459,"fPixeltoX":0.00817204304119592,"fAbsPixeltoYk":107.623090239262,"fPixeltoYk":-45.87054075472,"fPixeltoY":-0.325198370749962,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":1.48,"fUymin":0.1775514025164,"fUxmax":4.52,"fUymax":92.2737265680556,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"canvas","fTitle":"Histograma","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":496,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15; ...

# %%
# Fecha arquivo
file.Close()
